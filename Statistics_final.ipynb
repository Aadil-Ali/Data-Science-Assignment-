# %% [markdown]
# Q1) What is hypothesis testing in statistics.
#
# Hypothesis testing is a method used in statistics to test a hypothesis or statement about a population parameter, based on sample data. It involves comparing observed data to what we would expect under the null hypothesis..

# %% [markdown]
# Q2 What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
#
# Null Hypothesis (H0) - A statement that there is no effect or no difference,
# and it assumes that any observed effect in the data is due to random chance.
#
# Alternative Hypothesis (H1) - A statement that contradicts the null hypothesis, indicating that there is an effect or a difference.

# %% [markdown]
# Q3 What is the significance level in hypothesis testing, and why is it important*
#
#  Significance level (alpha) is the probability of rejecting the null hypothesis when it is actually true (Type I error). It is important because it sets the threshold for determining whether the observed data are statistically significant.

# %% [markdown]
# Q4 What does a P-value represent in hypothesis testing*
#
# A P-value represents the probability of obtaining the observed data, or more extreme, assuming the null hypothesis is true.

# %% [markdown]
# Q5 How do you interpret the P-value in hypothesis testing*
#
#  If the P-value is less than the significance level (alpha), we reject the null hypothesis. If the P-value is greater than the significance level, we fail to reject the null hypothesis.

# %% [markdown]
# Q6  What are Type 1 and Type 2 errors in hypothesis testing*
#
# Type 1 Error - Occurs when the null hypothesis is true, but we incorrectly reject it (false positive).
#
# Type 2 Error - Occurs when the null hypothesis is false, but we fail to reject it (false negative).

# %% [markdown]
# Q7 What is the difference between a one-tailed and a two-tailed test in hypothesis testing*
#
# One-tailed Test - Tests if the sample mean is significantly greater than or less than the population mean. Used when the alternative hypothesis is directional.
#
# Two-tailed Test - Tests if the sample mean is significantly different from the population mean in either direction. Used when the alternative hypothesis is non-directional.

# %% [markdown]
# Q8  What is the Z-test, and when is it used in hypothesis testing*
#
# If our sample size is greater than 30 and the standard deviation of the population is given, we use the Z-test. It is used in hypothesis testing for finding the mean difference between the population and the sample.

# %% [markdown]
# Q9 How do you calculate the Z-score, and what does it represent in hypothesis testing*
#
# To calculate the Z-score, divide the difference between the sample mean and the population mean by the standard error. The Z-score represents the number of standard deviations the sample mean is from the population mean in hypothesis testing.

# %% [markdown]
# Q10 What is the T-distribution, and when should it be used instead of the normal distribution*
#
# The T-distribution is used to find the difference between the population mean and the sample mean. If we have a sample size less than 30 and the population standard deviation is unknown, we use the T-test/T-distribution. It is close to the standard normal distribution.

# %% [markdown]
# Q11 What is the difference between a Z-test and a T-test*
#
#
# Sample Size: In the Z-test, the sample size is greater than 30, while in the T-test, the sample size is less than 30.
#
# Population Standard Deviation: In the Z-test, the population standard deviation is given, but in the T-test, the population standard deviation is not given.

# %% [markdown]
# Q12 What is the T-test, and how is it used in hypothesis testing*
#
# If the sample size is less than 30 and the population standard deviation is unknown, we use the T-test. It is used in hypothesis testing to find the mean difference between the population and the sample mean.

# %% [markdown]
# Q13 What is the relationship between Z-test and T-test in hypothesis testing*
#
# Both are used to find the mean difference between the population and the sample mean.

# %% [markdown]
# Q14 What is a confidence interval, and how is it used to interpret statistical results*
#
# A confidence interval is the range within which we can say that a certain percentage of our data lies. To find the confidence interval, we use the T-test or Z-test. It helps in interpreting statistical results by providing a range that is likely to contain the population parameter.

# %% [markdown]
# Q15 What is the margin of error, and how does it affect the confidence interval
#
# The margin of error is the value that indicates the range within which our hypothesis testing is likely to be accurate. If the margin of error is high, it means the range of the confidence interval is wide.

# %% [markdown]
# Q16  How is Bayes' Theorem used in statistics, and what is its significance
#
# Bayes' Theorem is used to find the probability of an event given that another event has occurred. It is significant in statistics for updating future results based on past data. It is used in the health sector for diagnosis, allowing us to update results and improve accuracy.

# %% [markdown]
# Q17 What is the Chi-square distribution, and when is it used
#
# The Chi-square distribution is used to find the variance difference in categorical variables. It has only one parameter, the degree of freedom, and is always right-skewed. If the degree of freedom increases, it becomes more similar to the normal distribution. It is used in the Chi-square test to determine if there is a significant difference between population variance and sample variance.

# %% [markdown]
# Q18  What is the Chi-square goodness of fit test, and how is it applied*
#
# The Chi-square goodness of fit test is used to determine how well the observed values fit the expected values in a sample. To apply it:
#
# Formulate the null hypothesis.
#
# Formulate the alternative hypothesis.
#
# Calculate the Chi-square statistic: (Observed Value - Expected Value)² / Expected Value.
#
# Compare the Chi-square statistic to the critical value (p-value). If the calculated value is greater than the critical value, reject the null hypothesis.

# %% [markdown]
# Q19 What is the F-distribution, and when is it used in hypothesis testing
#
# The F-distribution is used when we have more than three variables and we want to find the mean difference among these variables. It is used in the ANOVA test and regression analysis.

# %% [markdown]
# Q20  What is an ANOVA test, and what are its assumptions*
#
# Analysis of Variance (ANOVA) is used to find the mean variance among three or more variables. Assumptions for ANOVA include:
#
# Independence of observations.
#
# Homogeneity of variances.
#
# Normality of the distribution within groups.

# %% [markdown]
# Q21 What are the different types of ANOVA tests*
#
# One-way ANOVA: Compares the means of three or more groups based on one factor.
#
# Two-way ANOVA: Compares the means of groups based on two factors of analysis.

# %% [markdown]
# Q22 What is the F-test, and how does it relate to hypothesis testing?
#
# The F-test compares the variances of two or more groups to determine if they are significantly different. It calculates the F-statistic, which is the ratio of the variance between groups to the variance within groups. This statistic is then compared to a critical value from the F-distribution table.

# %% [markdown]
# #Practical

# %% [markdown]
# Q1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results

# %%
import numpy as np
from scipy.stats import norm
# Sample Data
sample_data = [4, 5, 6, 4, 2, 4, 2, 2, 1, 3, 1, 4, 5, 6, 8, 9, 0, 6, 5, 4, 3, 5, 7, 8, 9, 0, 7, 5, 4, 3, 5, 6, 7, 8, 9, 3, 4, 2, 3, 4, 5, 6, 7, 8, 2, 3, 4, 5, 7, 8, 9, 23, 4, 4, 3, 2, 4, 5, 6, 7, 8, 9]
sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

# Population mean
population_mean = 10
population_std = 2.5
alpha=0.05

# Z-score and p-value
z_score = (sample_mean - population_mean)/population_std/np.sqrt(sample_size)
p_value = 2*(1-norm.cdf(abs(z_score)))
sample_mean = np.mean(sample_data)

print(f"Z-score: {z_score}")
print(f"P-value: {p_value}")
print(f"Sample Mean: {sample_mean}")


# Interpret the results
if p_value < alpha:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# Z-score: -0.24416798610359206
# P-value: 0.8071007201755203
# Sample Mean: 5.193548387096774
# Fail to reject the null hypothesis

# %% [markdown]
# Q2 Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

# %%
import numpy as np
import scipy.stats as stats

# Generate random data
sample_data = np.random.normal(loc=10 , scale = 2.5, size = 100)
sample_mean = np.mean(sample_data)

population_mean = 10
population_std = 2.5
alpha = 0.05

# Perform two tails z test
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(len(sample_data)))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-score: {z_score}")
print(f"P-value: {p_value}")
print(f"Sample Mean: {sample_mean}")

#result
if p_value < alpha:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# Z-score: 0.28590585164885596
# P-value: 0.7749502317792323
# Sample Mean: 10.071476462912214
# Fail to reject the null hypothesis

# %% [markdown]
# Q3 Implement a one-sample Z-test using Python to compare the sample mean with the population mean

# %%
import numpy as np
import scipy.stats as stats

# Generate random data
sample_data = np.random.normal(loc=10 , scale = 2.5, size = 100)
sample_mean = np.mean(sample_data)

population_mean = 15
population_std = 2.5
alpha = 0.05

# Perform One tails z test
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(len(sample_data)))
p_value = stats.norm.cdf(z_score)

print(f"Z-score: {z_score}")
print(f"P-value: {p_value}")
print(f"Sample Mean: {sample_mean}")

#result
if p_value < alpha:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# Z-score: -19.657076304272692
# P-value: 2.5144301677981927e-86
# Sample Mean: 10.085730923931827
# Reject the null hypothesis

# %% [markdown]
# Q4 Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a two-tailed Z-test for a given sample mean against a known population mean and visualize the decision region.

    Parameters:
    sample (list or array): Sample data
    pop_mean (float): Known population mean
    pop_std (float): Known population standard deviation
    alpha (float): Significance level (default: 0.05)

    Returns:
    None
    """
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Compute Z-score
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))

    # Compute p-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Decision rule
    z_critical = stats.norm.ppf(1 - alpha / 2)  # Two-tailed critical value

    # Visualizing the decision regions
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label="Standard Normal Distribution")
    plt.axvline(-z_critical, color='red', linestyle='dashed', label=f"Critical Value -{z_critical:.2f}")
    plt.axvline(z_critical, color='red', linestyle='dashed', label=f"Critical Value {z_critical:.2f}")
    plt.axvline(z_score, color='blue', linestyle='solid', label=f"Z-score {z_score:.2f}")
    plt.fill_between(x, y, where=(x < -z_critical) | (x > z_critical), color='red', alpha=0.3, label="Rejection Region")

    plt.legend()
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.title("Two-tailed Z-test Decision Regions")
    plt.show()

    # Interpret the result
    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between sample and population means.")

# Simulate random sample data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=4, size=30)  # Normal distribution with mean 50 and std 4

# Population parameters
population_mean = 50
population_std = 4

# Perform the Z-test and visualize
test_result = z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.2474
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between sample and population means.

# %% [markdown]
# Q5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def z_test(sample, pop_mean, pop_std, alpha=0.05):
    """
    Perform a two-tailed Z-test for a given sample mean against a known population mean and visualize the decision region.
    """
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
    z_critical = stats.norm.ppf(1 - alpha / 2)

    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-score: {z_score:.4f}")
    print(f"P-value: {p_value:.4f}")

    if abs(z_score) > z_critical:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between sample and population means.")

def visualize_type1_error(alpha=0.05):
    """Visualize Type 1 error (False Positive)."""
    x = np.linspace(-4, 4, 1000)
    y_null = stats.norm.pdf(x, 0, 1)
    z_critical = stats.norm.ppf(1 - alpha)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y_null, label="Null Hypothesis (H0)", color='blue')
    plt.fill_between(x, y_null, where=(x > z_critical), color='red', alpha=0.3, label="Type 1 Error (α)")
    plt.axvline(z_critical, color='black', linestyle='dashed', label=f"Critical Value {z_critical:.2f}")

    plt.legend()
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.title("Type 1 Error in Hypothesis Testing")
    plt.show()

def visualize_type2_error(beta=0.2):
    """Visualize Type 2 error (False Negative)."""
    x = np.linspace(-4, 4, 1000)
    y_alt = stats.norm.pdf(x, 2, 1)
    z_critical = stats.norm.ppf(1 - beta)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y_alt, label="Alternative Hypothesis (H1)", color='green')
    plt.fill_between(x, y_alt, where=(x < z_critical), color='purple', alpha=0.3, label="Type 2 Error (β)")
    plt.axvline(z_critical, color='black', linestyle='dashed', label=f"Critical Value {z_critical:.2f}")

    plt.legend()
    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.title("Type 2 Error in Hypothesis Testing")
    plt.show()

np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=4, size=30)

population_mean = 50
population_std = 4

test_result = z_test(sample_data, population_mean, population_std)
visualize_type1_error()
visualize_type2_error()
# Out:
# Sample Mean: 49.2474
# Z-score: -1.0305
# P-value: 0.3028
# Fail to reject the null hypothesis: No significant difference between sample and population means.

# %% [markdown]
# Q6 Write a Python program to perform an independent T-test and interpret the results@

# %%
import numpy as np
import scipy.stats as stats
#random values
np.random.seed(20)
group1 = np.random.normal(loc=50 , scale=5 , size = 30)
group2 = np.random.normal(loc=40 , scale = 8 , size = 30)

t_stats , p_value = stats.ttest_ind(group1 , group2)
Significance_level = 0.05

if p_value < Significance_level:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")

print(f"T-statistic: {t_stats}")
print(f"P-value: {p_value}")
# Out:
# Reject the null hypothesis
# T-statistic: 4.6042709456992945
# P-value: 2.307047254684044e-05

# %% [markdown]
# Q7 Perform a paired sample T-test using Python and visualize the comparison results

# %%
import numpy as np
import scipy.stats as stats

#paired sample
before_treatment = np.random.normal(loc=50 , scale = 5 , size = 30)
after_treatment = before_treatment + np.random.normal(loc=1 , scale = 2 , size = 30)

t_stats , p_value = stats.ttest_rel(before_treatment , after_treatment)
Significance_level = 0.05

if p_value < Significance_level:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")

print(f"T-statistic: {t_stats}")
print(f"P-value: {p_value}")

# Plot Before Treatment
plt.subplot(1, 2, 1)
plt.hist(before_treatment, bins=10, alpha=0.7, color='blue', label='Before Treatment')
plt.axvline(np.mean(before_treatment), color='blue', linestyle='dashed', linewidth=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Before Treatment')
plt.legend()

# Plot After Treatment
plt.subplot(1, 2, 2)
plt.hist(after_treatment, bins=10, alpha=0.7, color='green', label='After Treatment')
plt.axvline(np.mean(after_treatment), color='green', linestyle='dashed', linewidth=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('After Treatment')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Reject the null hypothesis
# T-statistic: -4.034444807560943
# P-value: 0.0003643124712541234

# %% [markdown]
# Q8  Simulate data and perform both Z-test and T-test, then compare the results using Python

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Simulate Data
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=4, size=30)
group2 = np.random.normal(loc=52, scale=4, size=30)

# Population standard deviation (known for Z-test)
population_std = 4

# Step 2: Perform Z-test
def z_test(group1, group2, population_std):
    mean1 = np.mean(group1)
    mean2 = np.mean(group2)
    n1 = len(group1)
    n2 = len(group2)
    z_stat = (mean1 - mean2) / np.sqrt((population_std**2 / n1) + (population_std**2 / n2))
    p_value = 2 * (1 - stats.norm.cdf(np.abs(z_stat)))
    return z_stat, p_value

z_stat, z_p_value = z_test(group1, group2, population_std)

# Step 3: Perform T-test
t_stat, t_p_value = stats.ttest_ind(group1, group2)

# Step 4: Compare Results
alpha = 0.05
print("Z-test Results:")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {z_p_value:.4f}")

if z_p_value < alpha:
    print("Result: We reject the null hypothesis (H0). There is a significant difference between the two groups.")
else:
    print("Result: We fail to reject the null hypothesis (H0). There is no significant difference between the two groups.")

print("\nT-test Results:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {t_p_value:.4f}")

if t_p_value < alpha:
    print("Result: We reject the null hypothesis (H0). There is a significant difference between the two groups.")
else:
    print("Result: We fail to reject the null hypothesis (H0). There is no significant difference between the two groups.")

# Visualization
plt.figure(figsize=(10, 5))

# Plot Group 1
plt.subplot(1, 2, 1)
plt.hist(group1, bins=10, alpha=0.7, color='blue', label='Group 1')
plt.axvline(np.mean(group1), color='blue', linestyle='dashed', linewidth=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Group 1')
plt.legend()

# Plot Group 2
plt.subplot(1, 2, 2)
plt.hist(group2, bins=10, alpha=0.7, color='green', label='Group 2')
plt.axvline(np.mean(group2), color='green', linestyle='dashed', linewidth=1)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Group 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Z-test Results:
# Z-statistic: -2.1959
# P-value: 0.0281
# Result: We reject the null hypothesis (H0). There is a significant difference between the two groups.
#
# T-test Results:
# T-statistic: -2.3981
# P-value: 0.0197
# Result: We reject the null hypothesis (H0). There is a significant difference between the two groups.

# %% [markdown]
# Q9 Write a Python function to calculate the confidence interval for a sample mean and explain its significance

# %%
import numpy as np
import scipy.stats as stats

#generate sample data
np.random.seed(30)
group1 = np.random.normal(loc=50 , scale=4 , size=30)

#calculate sample mean and std
sample_mean = np.mean(group1)
sample_std = np.std(group1 , ddof=1)

#defineing the confidance level and calculating the corrosponding z score
confidence_level= 0.95
z_score = stats.norm.ppf(1-(1-confidence_level)/2)

#calculate the margin of error
margin_of_error = z_score*(sample_mean/np.sqrt(len(group1)))

#calculate the confidance interval
confidance_interval = (sample_mean-margin_of_error , sample_mean+margin_of_error)

print(f"Sample Mean: {sample_mean}")
print(f"Sample Standard Deviation: {sample_std}")
print(f"Z-score: {z_score}")
print(f"Margin of Error: {margin_of_error}")
print(f"Confidance Interval: {confidance_interval}")
#
# Out:
# Sample Mean: 49.89036510904703
# Sample Standard Deviation: 4.847730633724414
# Z-score: 1.959963984540054
# Margin of Error: 17.852709816203546
# Confidance Interval: (32.03765529284348, 67.74307492525058)

# %% [markdown]
# Q10 Write a Python program to calculate the margin of error for a given confidence level using sample data

# %%
import numpy as np
import scipy.stats as stats

#generate sample data
np.random.seed(30)
group1 = np.random.normal(loc=50 , scale=4 , size=30)

#calculate sample mean and std
sample_mean = np.mean(group1)
sample_std = np.std(group1 , ddof=1)



#finding z score and set confidence level
confidence_level = 0.95
z_score = stats.norm.ppf(1-(1-confidence_level)/2)

#now find the mirgen of error
mirgin_of_error = z_score*(sample_std/np.sqrt(len(group1)))

print(f"Sample Mean: {sample_mean}")
print(f"Sample Standard Deviation: {sample_std}")
print(f"Z-score: {z_score}")
print(f"Margin of Error: {mirgin_of_error}")
# Out:
# Sample Mean: 49.89036510904703
# Sample Standard Deviation: 4.847730633724414
# Z-score: 1.959963984540054
# Margin of Error: 1.734706252035597

# %% [markdown]
# Q11 Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# prior belief : beta distribution with alpha = 1  , beta = 1
alpha_prior = 1
beta_prior = 1

#observerd data 7 head , 3 tails
heads = 7
tails = 3

# posterior belief : beta distribution with update parameters
alpha_posterior = alpha_prior + heads
beta_posterior = beta_prior + tails

#plot prioe and poster distributions
x = np.linspace(0,1,100)
prior = stats.beta.pdf(x , alpha_prior , beta_prior)
posterior = stats.beta.pdf(x , alpha_posterior , beta_posterior)

plt.figure(figsize=(10,5))
plt.plot(x , prior , label = 'prior' , color = 'blue' )
plt.plot(x , posterior , label ='posterior' , color = 'red')
plt.fill_between(x,0,posterior , color='red' , alpha=0.3)
plt.xlabel('Probability of Heads')
plt.ylabel('Probability Density')
plt.title('Bayesian Inference')
plt.legend()
plt.show()
print(f"Updated alpha (posterior): {alpha_posterior}")
print(f"Updated beta (posterior): {beta_posterior}")
# Out:
# Updated alpha (posterior): 8
# Updated beta (posterior): 4

# %% [markdown]
# Q12 Perform a Chi-square test for independence between two categorical variables in Python

# %%
import pandas as pd
import scipy.stats as stats

#sample data : two categorical variable (gender and preference)

data = {'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
        'Preference': ['A', 'A', 'B', 'B', 'A', 'B', 'B', 'A']}

#create a dataframe
df =pd.DataFrame(data)

#create a contingency table
contingency_table = pd.crosstab(df['Gender'] , df['Preference'])

#perform chi square test
chi2 , p , dof , expeceted = stats.chi2_contingency(contingency_table)
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expeceted)

alpha = 0.05
if p < alpha:
    print("Result: We reject the null hypothesis. There is a significant association between Gender and Preference.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant association between Gender and Preference.")
# Out:
# Chi-square statistic: 0.0
# P-value: 1.0
# Degrees of freedom: 1
# Expected frequencies:
# [[2. 2.]
#  [2. 2.]]
# Result: We fail to reject the null hypothesis. There is no significant association between Gender and Preference.

# %% [markdown]
# Q13 Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data

# %%
import numpy as np
import pandas as pd

# Example: Observed frequencies in a contingency table
# Rows could represent different groups and columns could represent different categories.
# For example, we have 3 rows and 3 columns.
observed = np.array([
    [10, 20, 30],
    [20, 15, 25],
    [25, 30, 20]
])

# Calculate the totals for each row and each column, and the overall total.
row_totals = observed.sum(axis=1, keepdims=True)  # Sum along columns for each row
col_totals = observed.sum(axis=0, keepdims=True)    # Sum along rows for each column
grand_total = observed.sum()

# Calculate expected frequencies using the formula:
# Expected_ij = (Row Total_i * Column Total_j) / Grand Total
expected = (row_totals @ col_totals) / grand_total  # Using matrix multiplication (@)

# Display the results
print("Observed Frequencies:")
print(observed)
print("\nRow Totals:", row_totals.flatten())
print("Column Totals:", col_totals.flatten())
print("Grand Total:", grand_total)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Observed Frequencies:
# [[10 20 30]
#  [20 15 25]
#  [25 30 20]]
#
# Row Totals: [60 60 75]
# Column Totals: [55 65 75]
# Grand Total: 195
#
# Expected Frequencies:
# [[16.92307692 20.         23.07692308]
#  [16.92307692 20.         23.07692308]
#  [21.15384615 25.         28.84615385]]

# %% [markdown]
# Q14 Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

# %%
import numpy as np
import scipy.stats as stats

# Observed frequencies
observed = np.array([10, 20, 30])

# Expected frequencies (null hypothesis)
expected = np.array([15, 15, 30])

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = stats.chisquare(observed, expected)

# Display the results
print("Chi-square Goodness-of-Fit Test Results:")
print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. The observed frequencies significantly differ from the expected frequencies.")
else:
    print("Result: We fail to reject the null hypothesis. The observed frequencies do not significantly differ from the expected frequencies.")
# Out:
# Chi-square Goodness-of-Fit Test Results:
# Chi-square Statistic: 3.3333
# P-value: 0.1889
# Result: We fail to reject the null hypothesis. The observed frequencies do not significantly differ from the expected frequencies.

# %% [markdown]
# Q15 Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

#parameters
degree_of_freedom = 5
num_samples = 1000

#simulates chi square distribution
chi_square_sample = np.random.chisquare(degree_of_freedom , num_samples)

#plot histrograms
plt.figure(figsize=(10,6))
plt.hist(chi_square_sample , bins = 30 , alpha = 0.7 , color = 'blue' , label = 'Simulated Chi-square Distribution')

#plot theoretical chi square distribution
x = np.linspace(0 , np.max(chi_square_sample) , 1000)
chi_square_pdf = stats.chi2.pdf(x , degree_of_freedom)
plt.plot(x , chi_square_pdf , color = 'red' , label = 'Theoretical Chi-square Distribution')

#add labels
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Chi-square Distribution with {degree_of_freedom} Degrees of Freedom')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Q16 Implement an F-test using Python to compare the variances of two random samples

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Generate Random Samples
np.random.seed(42)
sample1 = np.random.normal(loc=10, scale=2, size=100)
sample2 = np.random.normal(loc=12, scale=3, size=100)

# Step 2: Calculate variances of the two samples
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# Calculate the F-statistic
F_stat = var1 / var2

# Step 3: Perform F-test
df1 = len(sample1) - 1  # Degrees of freedom for sample 1
df2 = len(sample2) - 1  # Degrees of freedom for sample 2
p_value = stats.f.cdf(F_stat, df1, df2)  # One-tailed test

# To get the two-tailed p-value
p_value = 2 * min(p_value, 1 - p_value)

# Display the results
print("F-test Results:")
print(f"Sample 1 Variance: {var1:.4f}")
print(f"Sample 2 Variance: {var2:.4f}")
print(f"F-statistic: {F_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. The variances of the two samples are significantly different.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant difference between the variances of the two samples.")
# Out:
# F-test Results:
# Sample 1 Variance: 3.2991
# Sample 2 Variance: 8.1854
# F-statistic: 0.4030
# P-value: 0.0000
# Result: We reject the null hypothesis. The variances of the two samples are significantly different.

# %% [markdown]
# Q17 Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Generate Sample Data
np.random.seed(42)
group1 = np.random.normal(loc=20, scale=5, size=30)
group2 = np.random.normal(loc=22, scale=5, size=30)
group3 = np.random.normal(loc=19, scale=5, size=30)

# Step 2: Perform ANOVA Test
f_stat, p_value = stats.f_oneway(group1, group2, group3)

# Step 3: Display and Interpret the Results
print("ANOVA Test Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. There is a significant difference between the group means.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant difference between the group means.")
# Out:
# ANOVA Test Results:
# F-statistic: 2.4531
# P-value: 0.0920
# Result: We fail to reject the null hypothesis. There is no significant difference between the group means.

# %% [markdown]
# Q18 Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Generate Sample Data
np.random.seed(42)
group1 = np.random.normal(loc=20, scale=5, size=30)
group2 = np.random.normal(loc=22, scale=5, size=30)
group3 = np.random.normal(loc=19, scale=5, size=30)
group4 = np.random.normal(loc=21, scale=5, size=30)

# Step 2: Perform ANOVA Test
f_stat, p_value = stats.f_oneway(group1, group2, group3, group4)

# Step 3: Display and Interpret the Results
print("ANOVA Test Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. There is a significant difference between the group means.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant difference between the group means.")

# Step 4: Plot the Results
plt.figure(figsize=(10, 6))
plt.boxplot([group1, group2, group3, group4], labels=['Group 1', 'Group 2', 'Group 3', 'Group 4'])
plt.title('Box Plot of Groups')
plt.xlabel('Group')
plt.ylabel('Values')
plt.show()
# Out:
# ANOVA Test Results:
# F-statistic: 2.0503
# P-value: 0.1107
# Result: We fail to reject the null hypothesis. There is no significant difference between the group means.
# <ipython-input-20-d8a968de80f4>:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3, group4], labels=['Group 1', 'Group 2', 'Group 3', 'Group 4'])

# %% [markdown]
# Q19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def check_anova_assumptions(*groups):
    """
    Check the assumptions (normality, independence, and equal variance) for ANOVA.

    Parameters:
    groups: Variable number of group arrays (each group as a separate argument).

    Returns:
    None
    """

    # Check Normality using Shapiro-Wilk test
    print("Normality Check using Shapiro-Wilk Test:")
    for i, group in enumerate(groups, start=1):
        stat, p_value = stats.shapiro(group)
        print(f"Group {i}: W = {stat:.4f}, p-value = {p_value:.4f}")
        if p_value < 0.05:
            print(f"Group {i}: Data is not normally distributed.")
        else:
            print(f"Group {i}: Data is normally distributed.")

    # Visualize Normality using Q-Q plots
    plt.figure(figsize=(15, 6))
    for i, group in enumerate(groups, start=1):
        plt.subplot(1, len(groups), i)
        stats.probplot(group, dist="norm", plot=plt)
        plt.title(f'Q-Q Plot Group {i}')
    plt.tight_layout()
    plt.show()

    # Check Homogeneity of Variance using Levene's test
    stat, p_value = stats.levene(*groups)
    print("\nHomogeneity of Variance Check using Levene's Test:")
    print(f"Levene's Test: W = {stat:.4f}, p-value = {p_value:.4f}")
    if p_value < 0.05:
        print("Variances are not equal across groups.")
    else:
        print("Variances are equal across groups.")

    # Visualize Homogeneity of Variance using box plots
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=groups)
    plt.title('Box Plot of Groups')
    plt.xlabel('Group')
    plt.ylabel('Values')
    plt.show()

    # Independence is assumed to be satisfied based on study design
    print("\nIndependence: Assumed to be satisfied based on study design.")

# Example usage
np.random.seed(42)
group1 = np.random.normal(loc=20, scale=5, size=30)
group2 = np.random.normal(loc=22, scale=5, size=30)
group3 = np.random.normal(loc=19, scale=5, size=30)

check_anova_assumptions(group1, group2, group3)
# Out:
# Normality Check using Shapiro-Wilk Test:
# Group 1: W = 0.9751, p-value = 0.6868
# Group 1: Data is normally distributed.
# Group 2: W = 0.9837, p-value = 0.9130
# Group 2: Data is normally distributed.
# Group 3: W = 0.9628, p-value = 0.3654
# Group 3: Data is normally distributed.
# Homogeneity of Variance Check using Levene's Test:
# Levene's Test: W = 0.1480, p-value = 0.8627
# Variances are equal across groups.
# Independence: Assumed to be satisfied based on study design.

# %% [markdown]
# Q20 Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as ols
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate Sample Data
np.random.seed(42)
factor1 = np.random.choice(['A', 'B'], size=60)
factor2 = np.random.choice(['X', 'Y'], size=60)
dependent_variable = np.random.normal(loc=10, scale=3, size=60) + \
                     (factor1 == 'B') * 2 + \
                     (factor2 == 'Y') * -1 + \
                     ((factor1 == 'B') & (factor2 == 'Y')) * 3

data = pd.DataFrame({'Factor1': factor1, 'Factor2': factor2, 'DependentVariable': dependent_variable})

# Step 2: Perform Two-Way ANOVA Test
model = ols.ols('DependentVariable ~ Factor1 * Factor2', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Step 3: Display and Interpret the Results
print("Two-Way ANOVA Test Results:")
print(anova_table)

# Check significance levels
alpha = 0.05
print("\nSignificance Results:")
for factor, row in anova_table.iterrows():
    print(f"{factor}: {'Significant' if row['PR(>F)'] < alpha else 'Not Significant'}")

# Step 4: Visualize the Results

# Interaction plot
interaction_plot = sns.pointplot(x='Factor1', y='DependentVariable', hue='Factor2', data=data, dodge=True, markers=['o', 's'], capsize=.1)
interaction_plot.set(title='Interaction Plot')
plt.show()

# Box plots
plt.figure(figsize=(10, 6))
sns.boxplot(x='Factor1', y='DependentVariable', hue='Factor2', data=data)
plt.title('Box Plot of Factors')
plt.xlabel('Factor1')
plt.ylabel('Dependent Variable')
plt.show()
# Out:
# Two-Way ANOVA Test Results:
#                      sum_sq    df          F        PR(>F)
# Factor1          267.616240   1.0  36.676022  1.231948e-07
# Factor2           35.758122   1.0   4.900546  3.093796e-02
# Factor1:Factor2   26.053577   1.0   3.570566  6.399310e-02
# Residual         408.618732  56.0        NaN           NaN
#
# Significance Results:
# Factor1: Significant
# Factor2: Significant
# Factor1:Factor2: Not Significant
# Residual: Not Significant

# %% [markdown]
# Q21 Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def visualize_f_distribution(df1, df2):
    """
    Visualize the F-distribution with given degrees of freedom.

    Parameters:
    df1 (int): Degrees of freedom for the numerator.
    df2 (int): Degrees of freedom for the denominator.

    Returns:
    None
    """
    # Generate x values
    x = np.linspace(0, 5, 500)

    # Compute the F-distribution PDF
    f_pdf = stats.f.pdf(x, df1, df2)

    # Plot the F-distribution
    plt.figure(figsize=(10, 6))
    plt.plot(x, f_pdf, 'r-', lw=2, label=f'F-distribution (df1={df1}, df2={df2})')
    plt.fill_between(x, 0, f_pdf, color='red', alpha=0.3)

    # Add labels and title
    plt.xlabel('F-value')
    plt.ylabel('Density')
    plt.title(f'F-distribution with df1={df1} and df2={df2}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
visualize_f_distribution(df1=5, df2=10)

# %% [markdown]
# Q22 Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate Sample Data
np.random.seed(42)
group1 = np.random.normal(loc=20, scale=5, size=30)
group2 = np.random.normal(loc=22, scale=5, size=30)
group3 = np.random.normal(loc=19, scale=5, size=30)
group4 = np.random.normal(loc=21, scale=5, size=30)

# Combine data into a DataFrame for visualization
data = pd.DataFrame({
    'Values': np.concatenate([group1, group2, group3, group4]),
    'Group': ['Group 1']*30 + ['Group 2']*30 + ['Group 3']*30 + ['Group 4']*30
})

# Step 2: Perform ANOVA Test
f_stat, p_value = stats.f_oneway(group1, group2, group3, group4)

# Step 3: Display and Interpret the Results
print("ANOVA Test Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. There is a significant difference between the group means.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant difference between the group means.")

# Step 4: Visualize the Results
plt.figure(figsize=(10, 6))
sns.boxplot(x='Group', y='Values', data=data)
plt.title('Box Plot of Group Means')
plt.xlabel('Group')
plt.ylabel('Values')
plt.show()
# Out:
# ANOVA Test Results:
# F-statistic: 2.0503
# P-value: 0.1107
# Result: We fail to reject the null hypothesis. There is no significant difference between the group means.

# %% [markdown]
# Q23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate Random Data
np.random.seed(42)
group1 = np.random.normal(loc=20, scale=5, size=50)
group2 = np.random.normal(loc=22, scale=5, size=50)

# Step 2: Perform Hypothesis Testing (Two-sample t-test)
t_stat, p_value = stats.ttest_ind(group1, group2)

# Step 3: Display and Interpret the Results
print("Two-Sample T-Test Results:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Result: We reject the null hypothesis. There is a significant difference between the group means.")
else:
    print("Result: We fail to reject the null hypothesis. There is no significant difference between the group means.")

# Visualize the Results
plt.figure(figsize=(10, 6))
sns.histplot(group1, kde=True, color='blue', label='Group 1')
sns.histplot(group2, kde=True, color='green', label='Group 2')
plt.title('Distribution of Two Groups')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Two-Sample T-Test Results:
# T-statistic: -3.5559
# P-value: 0.0006
# Result: We reject the null hypothesis. There is a significant difference between the group means.

# %% [markdown]
# Q24  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

# %%
import scipy.stats as stats

# Sample data
sample_variance = 20
sample_size = 15
population_variance = 25
alpha = 0.05

# Test statistic
chi_square_statistic = (sample_size - 1) * sample_variance / population_variance

# Degrees of freedom
degrees_of_freedom = sample_size - 1

# Critical values
chi_square_critical_low = stats.chi2.ppf(alpha / 2, degrees_of_freedom)
chi_square_critical_high = stats.chi2.ppf(1 - alpha / 2, degrees_of_freedom)

# Decision
if chi_square_statistic < chi_square_critical_low or chi_square_statistic > chi_square_critical_high:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

# Output results
print(f"Chi-square statistic: {chi_square_statistic:.2f}")
print(f"Critical values: {chi_square_critical_low:.2f}, {chi_square_critical_high:.2f}")
print(f"Decision: {decision}")
# Out:
# Chi-square statistic: 11.20
# Critical values: 5.63, 26.12
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# Q25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

# %%
import numpy as np
import scipy.stats as stats

def z_test_proportions(count1, nobs1, count2, nobs2, alpha=0.05):
    # Proportions
    prop1 = count1 / nobs1
    prop2 = count2 / nobs2

    # Pooled proportion
    pooled_prop = (count1 + count2) / (nobs1 + nobs2)

    # Standard error
    se = np.sqrt(pooled_prop * (1 - pooled_prop) * (1/nobs1 + 1/nobs2))

    # Z statistic
    z_stat = (prop1 - prop2) / se

    # P-value
    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    # Critical value
    z_critical = stats.norm.ppf(1 - alpha / 2)

    # Decision
    if abs(z_stat) > z_critical:
        decision = "Reject the null hypothesis"
    else:
        decision = "Fail to reject the null hypothesis"

    return {
        "z_stat": z_stat,
        "p_value": p_value,
        "z_critical": z_critical,
        "decision": decision
    }

# Example usage
count1 = 50  # Number of successes in group 1
nobs1 = 200  # Number of observations in group 1
count2 = 30  # Number of successes in group 2
nobs2 = 180  # Number of observations in group 2
alpha = 0.05

result = z_test_proportions(count1, nobs1, count2, nobs2, alpha)

print(f"Z statistic: {result['z_stat']:.2f}")
print(f"P-value: {result['p_value']:.4f}")
print(f"Critical value: {result['z_critical']:.2f}")
print(f"Decision: {result['decision']}")
# Out:
# Z statistic: 1.99
# P-value: 0.0466
# Critical value: 1.96
# Decision: Reject the null hypothesis

# %% [markdown]
# Q26 Implement an F-test for comparing the variances of two datasets, then interpret and visualize the result

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Generate two sample datasets
np.random.seed(42)
data1 = np.random.normal(loc=20, scale=5, size=100)
data2 = np.random.normal(loc=20, scale=10, size=100)

# Calculate sample variances
var1 = np.var(data1, ddof=1)
var2 = np.var(data2, ddof=1)

# Perform F-test
f_stat = var1 / var2
df1 = len(data1) - 1
df2 = len(data2) - 1
p_value = stats.f.cdf(f_stat, df1, df2) if f_stat < 1 else 1 - stats.f.cdf(1 / f_stat, df2, df1)

# Determine critical value
alpha = 0.05
f_critical_low = stats.f.ppf(alpha / 2, df1, df2)
f_critical_high = stats.f.ppf(1 - alpha / 2, df1, df2)

# Decision
if f_stat < f_critical_low or f_stat > f_critical_high:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

# Output results
print(f"F statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Critical values: {f_critical_low:.2f}, {f_critical_high:.2f}")
print(f"Decision: {decision}")

# Visualize the data
plt.boxplot([data1, data2], labels=['Data1', 'Data2'])
plt.title('Boxplot of Two Datasets')
plt.ylabel('Values')
plt.show()
# Out:
# F statistic: 0.23
# P-value: 0.0000
# Critical values: 0.67, 1.49
# Decision: Reject the null hypothesis
# <ipython-input-30-a1f6deed8bd8>:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Data1', 'Data2'])

# %% [markdown]
# Q27 Perform a Chi-square test for goodness of fit with simulated data and analyze the results

# %%
import numpy as np
from scipy.stats import chisquare

# Simulate observed data
observed = np.array([35, 40, 25])

# Expected frequencies (based on your hypothesis)
expected = np.array([30, 40, 30])

# Perform Chi-square test
chi2_stat, p_val = chisquare(observed, expected)

# Display results
print(f"Chi-square Statistic: {chi2_stat}")
print(f"P-value: {p_val}")
# Out:
# Chi-square Statistic: 1.6666666666666667
# P-value: 0.4345982085070783

# %% [markdown]
# Analysis:
# Chi-square Statistic: 1.6667
#
# P-value: 0.4346
#
# In this case, the p-value is greater than 0.05, meaning we fail to reject the null hypothesis. There isn't enough evidence to suggest that the observed frequencies significantly differ from the expected frequencies.
